# %% [markdown]
# # Visualization with Hierarchical Clustering and t-SNE

# %% [markdown]
# ## Hierarchical clustering of the grain data

# %%
import pandas as pd
samples = pd.read_csv("datasets/grains.csv", encoding="UTF-8")
movements = pd.read_csv('datasets/company-stock-movements-2010-2015-incl.csv', index_col=0)
eurovision = pd.read_csv('datasets/eurovision-2016.csv')
'''
I think I need to pre-process those data first
'''
# Out:
# '\nI think I need to pre-process those data first\n'

# %%
samples.head()
# Out:
#        0      1       2      3      4      5      6  variety_number  \
# 0  15.26  14.84  0.8710  5.763  3.312  2.221  5.220               1
# 1  14.88  14.57  0.8811  5.554  3.333  1.018  4.956               1
# 2  14.29  14.09  0.9050  5.291  3.337  2.699  4.825               1
# 3  13.84  13.94  0.8955  5.324  3.379  2.259  4.805               1
# 4  16.14  14.99  0.9034  5.658  3.562  1.355  5.175               1
#
#       variety
# 0  Kama wheat
# 1  Kama wheat
# 2  Kama wheat
# 3  Kama wheat
# 4  Kama wheat

# %%
movements.head()
# Out:
#                   2010-01-04  2010-01-05  2010-01-06  2010-01-07  2010-01-08  \
# Apple               0.580000   -0.220005   -3.409998   -1.170000    1.680011
# AIG                -0.640002   -0.650000   -0.210001   -0.420000    0.710001
# Amazon             -2.350006    1.260009   -2.350006   -2.009995    2.960006
# American express    0.109997    0.000000    0.260002    0.720002    0.190003
# Boeing              0.459999    1.770000    1.549999    2.690003    0.059997
#
#                   2010-01-11  2010-01-12  2010-01-13  2010-01-14  2010-01-15  \
# Apple              -2.689994   -1.469994    2.779997   -0.680003   -4.999995
# AIG                -0.200001   -1.130001    0.069999   -0.119999   -0.500000
# Amazon             -2.309997   -1.640007    1.209999   -1.790001   -2.039994
# American express   -0.270001    0.750000    0.300004    0.639999   -0.130001
# Boeing             -1.080002    0.360000    0.549999    0.530002   -0.709999
#
# ...

# %%
eurovision.head()
# Out:
#   From country       To country  Jury A  Jury B  Jury C  Jury D  Jury E  \
# 0      Albania          Belgium      20      16      24      22      24
# 1      Albania   Czech Republic      21      15      25      23      16
# 2      Albania  The Netherlands      22      14      23      24      21
# 3      Albania       Azerbaijan      19      12      11      21      11
# 4      Albania          Hungary       8      13       9      14       9
#
#    Jury Rank  Televote Rank  Jury Points  Televote Points
# 0         25             14          NaN              NaN
# 1         22             22          NaN              NaN
# 2         24             24          NaN              NaN
# 3         13             19          NaN              NaN
# 4         10             10          1.0              1.0

# %%
# Perform the necessary imports
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

# Calculate the linkage: mergings
mergings = linkage(samples, method='complete')

# Plot the dendrogram, using varieties as labels
dendrogram(mergings,
           labels=varieties,
           leaf_rotation=90,
           leaf_font_size=6,
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2v/y67bw0ns14dgv1d58t7nwsxh0000gn/T/ipykernel_11901/1315099802.py in <module>
#       4
#       5 # Calculate the linkage: mergings
# ----> 6 mergings = linkage(samples, method='complete')
#       7
#       8 # Plot the dendrogram, using varieties as labels
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/cluster/hierarchy.py in linkage(y, method, metric, optimal_ordering)
#    1044         raise ValueError("Invalid method: {0}".format(method))
#    1045
# -> 1046     y = _convert_to_double(np.asarray(y, order='c'))
#    1047
#    1048     if y.ndim == 1:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/cluster/hierarchy.py in _convert_to_double(X)
#    1570 def _convert_to_double(X):
#    1571     if X.dtype != np.double:
# -> 1572         X = X.astype(np.double)
#    1573     if not X.flags.contiguous:
# ...

# %% [markdown]
# ## Hierarchies of stocks

# %%
# Import normalize
from sklearn.preprocessing import normalize

# Normalize the movements: normalized_movements
normalized_movements = normalize(movements)

# Calculate the linkage: mergings
mergings = linkage(normalized_movements, method='complete')

# Plot the dendrogram
dendrogram(mergings, labels=companies, leaf_rotation=90, leaf_font_size=6)
plt.show()

'''
Scipy cluster labels start at 1, not at 0 like they do in scikit-learn
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2v/y67bw0ns14dgv1d58t7nwsxh0000gn/T/ipykernel_11901/2107708843.py in <module>
#       9
#      10 # Plot the dendrogram
# ---> 11 dendrogram(mergings, labels=companies, leaf_rotation=90, leaf_font_size=6)
#      12 plt.show()
#      13
#
# NameError: name 'companies' is not defined

# %% [markdown]
# ## Different linkage, different hierarchical clustering!

# %%
# Perform the necessary imports
'''
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram
'''

# Calculate the linkage: mergings
mergings = linkage(eurovision, method='single')

# Plot the dendrogram
dendrogram(mergings, labels=country_names, leaf_rotation=90, leaf_font_size=6)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2v/y67bw0ns14dgv1d58t7nwsxh0000gn/T/ipykernel_11901/951588317.py in <module>
#       6
#       7 # Calculate the linkage: mergings
# ----> 8 mergings = linkage(eurovision, method='single')
#       9
#      10 # Plot the dendrogram
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/cluster/hierarchy.py in linkage(y, method, metric, optimal_ordering)
#    1044         raise ValueError("Invalid method: {0}".format(method))
#    1045
# -> 1046     y = _convert_to_double(np.asarray(y, order='c'))
#    1047
#    1048     if y.ndim == 1:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/cluster/hierarchy.py in _convert_to_double(X)
#    1570 def _convert_to_double(X):
#    1571     if X.dtype != np.double:
# -> 1572         X = X.astype(np.double)
#    1573     if not X.flags.contiguous:
# ...

# %% [markdown]
# ## Extracting the cluster labels

# %%
# Perform the necessary imports
#import pandas as pd
from scipy.cluster.hierarchy import fcluster

# Use fcluster to extract labels: labels
labels = fcluster(mergings, 6, criterion='distance')

# Create a DataFrame with labels and varieties as columns: df
df = pd.DataFrame({'labels': labels, 'varieties': varieties})

# Create crosstab: ct
ct = pd.crosstab(df['labels'], df['varieties'])

# Display ct
print(ct)

# %% [markdown]
# ## t-SNE visualization of grain dataset

# %%
'''
t-SNE
- t-SNE stans for t-distributed stochastic neighbor embedding

Cons of t-SNE
1. t-SNE does not have separate fit and transform methods. It means that you can't extend t-SNE map to include new smaples.
2. Learning rate
- Choose learning rate for the dataset
- Wrong choice: points bunch together
- Try values between 50 and 200
3. Different every time
- t-SNE features are different every time
- e.g. t-SNE plots of the same samples generate different plots when using the same code.
'''


# Import TSNE
from sklearn.manifold import TSNE

# Create a TSNE instance: model
model = TSNE(learning_rate=200)

# Apply fit_transform to samples: tsne_features
tsne_features = model.fit_transform(samples)

# Select the 0th feature: xs
xs = tsne_features[:,0]

# Select the 1st feature: ys
ys = tsne_features[:,1]

# Scatter plot, coloring by variety_numbers
plt.scatter(xs, ys, c=variety_numbers)
plt.show()

# %% [markdown]
# ## A t-SNE map of the stock market

# %%
# Import TSNE
#from sklearn.manifold import TSNE

# Create a TSNE instance: model
model = TSNE(learning_rate=50)

# Apply fit_transform to normalized_movements: tsne_features
tsne_features = model.fit_transform(normalized_movements)

# Select the 0th feature: xs
xs = tsne_features[:,0]

# Select the 1th feature: ys
ys = tsne_features[:,1]

# Scatter plot
plt.scatter(xs, ys, alpha=0.5)

# Annotate the points
for x, y, company in zip(xs, ys, companies):
    plt.annotate(company, (x, y), fontsize=5, alpha=0.75)
plt.show()
